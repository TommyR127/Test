# %%
print("hello my name is tommy")
# Out:
# hello my name is tommy

# %%
print("testing new branch")
# Out:
# testing new branch

# %%
print("test another")
# Out:
# test another

# %%
print("am i on master")
# Out:
# am i on master
